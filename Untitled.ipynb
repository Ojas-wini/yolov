# %%
# !python -m pip install --upgrade pip
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# !pip install tensorflow==2.3.1
# Out:
# ...
#      -------------------------------------- 12.8/12.8 MB 168.3 kB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/22/cb/21a148329591931d8764e7ef49cb19586dd5b5e002a184988cb5ec1ccba9/numpy-1.18.5-cp38-cp38-win_amd64.whl
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# ...

# %%
# !pip install tensorboard==2.4.1
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# !pip install urllib3==1.26.6
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# !pip install --upgrade --user pyqt5==5.12
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# !pip install PyQtWebEngine==5.12
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# !pip install torch
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# C:\Users\akula\anaconda3\envs\yolov\trialyo\yolov5

# %%
# %pip install -qr requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
# %pip install -q roboflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)

# %%
import torch
import os
from IPython.display import Image, clear_output  

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.1+cpu (CPU)

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
import os
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rV2mQJ3CFbrIBgO2ilr8")
project = rf.workspace("yolocustom").project("final_data-fem8p")
dataset = project.version(2).download("yolov5")
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akula\anaconda3\lib\site-packages)
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/final_data-2 in yolov5pytorch:: 100%|██████████| 212/212 [00:00<00:00, 317.22it/s]

# %%
# !python train.py --img 416 --batch 50 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 416 --conf 0.5 --source {dataset.location}/test/images
# Out:
# C:\Users\akula\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# detect: weights=['runs/train/exp3/weights/best.pt'], source=C:\content\datasets\final_data-2/test/images, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-246-ge40662f Python-3.8.3 torch-1.12.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('runs/detect/exp2/*.jpg'):
    display(Image(filename=imageName))
    print("\n")
